# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("college_student_placement_dataset.csv")

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# 3                   1        No
# 4                   2        No

# %%
df.describe()
# Out:
#                  IQ  Prev_Sem_Result          CGPA  Academic_Performance  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      99.471800         7.535673      7.532379              5.546400
# std       15.053101         1.447519      1.470141              2.873477
# min       41.000000         5.000000      4.540000              1.000000
# 25%       89.000000         6.290000      6.290000              3.000000
# 50%       99.000000         7.560000      7.550000              6.000000
# 75%      110.000000         8.790000      8.770000              8.000000
# max      158.000000        10.000000     10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count            10000.000000          10000.000000        10000.000000
# mean                 4.970900              5.561800            2.513400
# std                  3.160103              2.900866            1.715959
# min                  0.000000              1.000000            0.000000
# 25%                  2.000000              3.000000            1.000000
# 50%                  5.000000              6.000000            3.000000
# 75%                  8.000000              8.000000            4.000000
# max                 10.000000             10.000000            5.000000

# %%
df.isnull().sum()
# Out:
# College_ID                0
# IQ                        0
# Prev_Sem_Result           0
# CGPA                      0
# Academic_Performance      0
# Internship_Experience     0
# Extra_Curricular_Score    0
# Communication_Skills      0
# Projects_Completed        0
# Placement                 0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# 3                   1        No
# 4                   2        No

# %%
df = df.drop(['College_ID'], axis=1)
df.head()
# Out:
#     IQ  Prev_Sem_Result  CGPA  Academic_Performance Internship_Experience  \
# 0  107             6.61  6.28                     8                    No
# 1   97             5.52  5.37                     8                    No
# 2  109             5.36  5.83                     9                    No
# 3  122             5.47  5.75                     6                   Yes
# 4   96             7.91  7.69                     7                    No
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed Placement
# 0                       8                     8                   4        No
# 1                       7                     8                   0        No
# 2                       3                     1                   1        No
# 3                       1                     6                   1        No
# 4                       8                    10                   2        No

# %%
df = pd.get_dummies(df, columns=['Internship_Experience', 'Placement'], drop_first=True)

# %%
df
# Out:
#        IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0     107             6.61  6.28                     8
# 1      97             5.52  5.37                     8
# 2     109             5.36  5.83                     9
# 3     122             5.47  5.75                     6
# 4      96             7.91  7.69                     7
# ...   ...              ...   ...                   ...
# 9995  119             8.41  8.29                     4
# 9996   70             9.25  9.34                     7
# 9997   89             6.08  6.25                     3
# 9998  107             8.77  8.92                     3
# 9999  109             9.41  9.77                     8
#
#       Extra_Curricular_Score  Communication_Skills  Projects_Completed  \
# 0                          8                     8                   4
# 1                          7                     8                   0
# 2                          3                     1                   1
# 3                          1                     6                   1
# 4                          8                    10                   2
# ...                      ...                   ...                 ...
# 9995                       1                     8                   0
# 9996                       0                     7                   2
# 9997                       3                     9                   5
# 9998                       7                     5                   1
# 9999                       3                     5                   5
#
#       Internship_Experience_Yes  Placement_Yes
# 0                         False          False
# 1                         False          False
# 2                         False          False
# 3                          True          False
# 4                         False          False
# ...                         ...            ...
# 9995                      False           True
# 9996                      False          False
# 9997                       True          False
# 9998                      False          False
# 9999                      False          False
#
# [10000 rows x 9 columns]

# %%
df.head()
# Out:
#     IQ  Prev_Sem_Result  CGPA  Academic_Performance  Extra_Curricular_Score  \
# 0  107             6.61  6.28                     8                       8
# 1   97             5.52  5.37                     8                       7
# 2  109             5.36  5.83                     9                       3
# 3  122             5.47  5.75                     6                       1
# 4   96             7.91  7.69                     7                       8
#
#    Communication_Skills  Projects_Completed  Internship_Experience_Yes  \
# 0                     8                   4                      False
# 1                     8                   0                      False
# 2                     1                   1                      False
# 3                     6                   1                       True
# 4                    10                   2                      False
#
#    Placement_Yes
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False

# %%
x = df.drop('Placement_Yes', axis=1)
y = df['Placement_Yes']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42)
}

# %%
for name, model in models.items():
    model.fit(x_train, y_train)
    score = model.score(x_test, y_test)  # This gives R² score
    print(f"{name}: Score = {score:.4f}")
# Out:
# Logistic Regression: Score = 0.9040
# Decision Tree: Score = 1.0000
# Random Forest: Score = 1.0000

# %%
model.predict(np.array([[80, 6.6, 7.7, 0, 3.9, 4.0, 3]]))  # Example input for prediction
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 model.predict(np.array([[80, 6.6, 7.7, 0, 3.9, 4.0, 3]]))
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:638, in BaseForest._validate_X_predict(self, X)
#     635 else:
#     636     ensure_all_finite = True
# --> 638 X = validate_data(
#     639     self,
#     640     X,
#     641     dtype=DTYPE,
#     642     accept_sparse="csr",
#     643     reset=False,
#     644     ensure_all_finite=ensure_all_finite,
#     645 )
#     646 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     647     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2965, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965     _check_n_features(_estimator, X, reset=reset)
#    2967 return out
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2829, in _check_n_features(estimator, X, reset)
#    2826     return
#    2828 if n_features != estimator.n_features_in_:
# -> 2829     raise ValueError(
#    2830         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831         f"is expecting {estimator.n_features_in_} features as input."
#    2832     )
#
# ValueError: X has 7 features, but RandomForestClassifier is expecting 8 features as input.
